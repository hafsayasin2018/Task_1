# %% [markdown]
# ## Import Libraries:

# %%
import pandas as pd
import os
import numpy as np

# %% [markdown]
# ## Set path and merge multi-files of dataset:

# %%
#path = "./Sales_Data"
data_set = pd.read_csv(r"C:\Users\Hafsa\Pandas\pandas_project\Sales_Analyses\SalesAnalysis\Sales_Data\Sales_April_2019.csv")
data_set
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
Data_set = r"C:\Users\Hafsa\Pandas\pandas_project\Sales_Analyses\SalesAnalysis\Sales_Data"
Sales_files = [file for file in os.listdir(Data_set) if not file.startswith('.')] # Ignore hidden files

all_months_data = pd.DataFrame()

for file in Sales_files:
    current_data = pd.read_csv(Data_set+"/"+file)
    all_months_data = pd.concat([all_months_data, current_data])
    
all_months_data.to_csv("all_data_copy1.csv", index=False)

# %%
all_data = pd.read_csv("all_data_copy1.csv")
all_data.head() # return first 5 entites
all_data.tail() # return last 5 entites
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 186845   259353  AAA Batteries (4-pack)                3       2.99
# 186846   259354                  iPhone                1        700
# 186847   259355                  iPhone                1        700
# 186848   259356  34in Ultrawide Monitor                1     379.99
# 186849   259357    USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016

# %%
all_data.head(10)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
# 6   176562        USB-C Charging Cable                1      11.95
# 7   176563  Bose SoundSport Headphones                1      99.99
# 8   176564        USB-C Charging Cable                1      11.95
# 9   176565          Macbook Pro Laptop                1       1700
#
#        Order Date                        Purchase Address
# 0  04/19/19 08:46            917 1st St, Dallas, TX 75001
# 1             NaN                                     NaN
# ...

# %% [markdown]
# Clean up data:

# %%
# drop NAN values
nan_df = all_data[all_data.isna().any(axis=1)]
display(nan_df.head())

all_data = all_data.dropna(how='all')
all_data.head()
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address, Month]
# Index: []
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %% [markdown]
# ### Get rid of text in column

# %%
# Get rid r in order date colmun
all_data = all_data[all_data['Order Date'].str[0:2]!='Or']

# %% [markdown]
# ### Make data correct type:

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

# %% [markdown]
# ### Apply describe() in different way:

# %%
all_data.describe() # all func of describe
# Out:
#        Quantity Ordered     Price Each          Month
# count     185950.000000  185950.000000  185950.000000
# mean           1.124383     184.399735       7.059140
# std            0.442793     332.731330       3.502996
# min            1.000000       2.990000       1.000000
# 25%            1.000000      11.950000       4.000000
# 50%            1.000000      14.950000       7.000000
# 75%            1.000000     150.000000      10.000000
# max            9.000000    1700.000000      12.000000

# %%
all_data.describe().loc[['count','std']] # applied count and standard deviation
# Out:
#        Quantity Ordered    Price Each          Month
# count     185950.000000  185950.00000  185950.000000
# std            0.442793     332.73133       3.502996

# %%
all_data.describe().loc[['std']] # applied count and standard deviation
# Out:
#      Quantity Ordered  Price Each     Month
# std          0.442793   332.73133  3.502996

# %%
all_data.groupby('Quantity Ordered')['Month'].describe() #find statistics of month by Quantity Ordered
# Out:
#                      count      mean       std  min   25%   50%   75%   max
# Quantity Ordered
# 1                 168552.0  7.058949  3.503961  1.0  4.00   7.0  10.0  12.0
# 2                  13324.0  7.061243  3.483289  1.0  4.00   7.0  10.0  12.0
# 3                   2920.0  7.027740  3.542274  1.0  4.00   7.0  10.0  12.0
# 4                    806.0  7.178660  3.507272  1.0  4.00   7.0  10.0  12.0
# 5                    236.0  6.766949  3.425923  1.0  4.00   7.0  10.0  12.0
# 6                     80.0  7.662500  3.525472  1.0  4.75   7.0  11.0  12.0
# 7                     24.0  7.500000  3.764826  1.0  4.75   8.0  11.0  12.0
# 8                      5.0  9.200000  1.643168  7.0  8.00  10.0  10.0  11.0
# 9                      3.0  6.666667  0.577350  6.0  6.50   7.0   7.0   7.0

# %% [markdown]
# ### Select Subsets of dataset :

# %%
price_product = all_data[["Price Each","Month"]]

price_product.tail(10)
# Out:
#         Price Each  Month
# 186840        2.99      9
# 186841      600.00      9
# 186842       11.95      9
# 186843      150.00      9
# 186844       11.95      9
# 186845        2.99      9
# 186846      700.00      9
# 186847      700.00      9
# 186848      379.99      9
# 186849       11.95      9

# %%
all_data[["Price Each","Quantity Ordered"]].shape
# Out:
# (185950, 2)

# %% [markdown]
# ### Apply arithmatic operations:

# %%
# apply greater_than operator
greater = all_data[all_data["Price Each"]>700]
greater.head(20)
# Out:
#     Order ID             Product  Quantity Ordered  Price Each  \
# 9     176565  Macbook Pro Laptop                 1     1700.00
# 80    176633     ThinkPad Laptop                 1      999.99
# 86    176639  Macbook Pro Laptop                 1     1700.00
# 90    176643  Macbook Pro Laptop                 1     1700.00
# 93    176646  Macbook Pro Laptop                 1     1700.00
# 104   176657     ThinkPad Laptop                 1      999.99
# 112   176665     ThinkPad Laptop                 1      999.99
# 130   176681     ThinkPad Laptop                 1      999.99
# 136   176687  Macbook Pro Laptop                 1     1700.00
# 198   176747  Macbook Pro Laptop                 1     1700.00
# 200   176749     ThinkPad Laptop                 1      999.99
# 262   176806  Macbook Pro Laptop                 1     1700.00
# 324   176866     ThinkPad Laptop                 1      999.99
# 336   176878     ThinkPad Laptop                 1      999.99
# ...

# %%
# apply less_than operator
less = all_data[all_data["Month"]<10]
less.tail(10)
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 186840   259349    AAA Batteries (4-pack)                 1        2.99
# 186841   259350              Google Phone                 1      600.00
# 186842   259350      USB-C Charging Cable                 1       11.95
# 186843   259351  Apple Airpods Headphones                 1      150.00
# 186844   259352      USB-C Charging Cable                 1       11.95
# 186845   259353    AAA Batteries (4-pack)                 3        2.99
# 186846   259354                    iPhone                 1      700.00
# 186847   259355                    iPhone                 1      700.00
# 186848   259356    34in Ultrawide Monitor                 1      379.99
# 186849   259357      USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month
# 186840  09/01/19 22:14           911 River St, Dallas, TX 75001      9
# ...

# %%
# apply equal operator:
equal = all_data[all_data["Month"] == 10]
equal.head(15)
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 154785   259358    34in Ultrawide Monitor                 1      379.99
# 154786   259359    27in 4K Gaming Monitor                 1      389.99
# 154787   259360    AAA Batteries (4-pack)                 2        2.99
# 154788   259361          27in FHD Monitor                 1      149.99
# 154789   259362          Wired Headphones                 1       11.99
# 154790   259363    AAA Batteries (4-pack)                 1        2.99
# 154791   259364          Wired Headphones                 1       11.99
# 154792   259365  Lightning Charging Cable                 1       14.95
# 154793   259366  Apple Airpods Headphones                 1      150.00
# 154794   259367  Apple Airpods Headphones                 1      150.00
# 154795   259368          27in FHD Monitor                 1      149.99
# 154796   259369      USB-C Charging Cable                 1       11.95
# ...

# %%
# apply unequal operator:
unequal = all_data[all_data["Month"] != 10]
unequal
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month
# ...

# %% [markdown]
# # <center>Today's Task</center>
# ### <center>First we need to find out how many different products available in dataframe with price and quantity:</center>

# %%
#count_products
product_by_price = all_data.groupby('Price Each')['Product'].count()
product_by_quantity = all_data.groupby('Quantity Ordered')['Product'].count()
print("Product avaliable with price")
print("\n")
print(product_by_price)
print("\n")
print("-----------------------------")
print("Product avaliable with quantity")
print(product_by_quantity)
# Out:
# Product avaliable with price
#
#
# Price Each
# 2.99       20641
# 3.84       20577
# 11.95      21903
# 11.99      18882
# 14.95      21658
# 99.99      13325
# 109.99      4101
# 149.99      7507
# 150.00     15549
# 300.00      4800
# 379.99      6181
# 389.99      6230
# 400.00      2065
# 600.00      6837
# 700.00      6842
# 999.99      4128
# 1700.00     4724
# Name: Product, dtype: int64
#
#
# -----------------------------
# Product avaliable with quantity
# Quantity Ordered
# 1    168552
# 2     13324
# 3      2920
# 4       806
# 5       236
# 6        80
# 7        24
# 8         5
# 9         3
# Name: Product, dtype: int64

# %% [markdown]
# ### <center>Task completed</center>
